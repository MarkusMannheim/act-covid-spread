# %%
import pandas as pd
import time
from geopy.geocoders import GoogleV3

data = pd.read_csv("data.tsv", sep="\t", usecols=["Exposure Location", "Street", "Suburb", "Date", "Contact"])
data.columns = ["location", "street", "suburb", "date", "contact"]
# data["date"] = pd.to_datetime(data["date"], format="%d/%m/%Y - %A")
# data.sort_values("date", inplace=True)

geolocator = GoogleV3(api_key="AIzaSyDwoN6b6VnZhTNrK65LC6B4vcnskrI3EeA")

# for i in data.index[:5]:
#     address = f"{data.at[i, 'location']}, {data.at[i, 'street']}, {data.at[i, 'suburb']}, ACT Australia"
#     location = geolocator.geocode(address)
#     try:        
#         data.at[i, "lng"] = location.longitude
#         data.at[i, "lat"] = location.latitude
#     except:
#         print(data.loc[i])
data
# Out:
#                                          location                     street  \
# 0                      Gerald Slaven Ford Phillip           29 Botany Street
# 1                                42 Halley Street                   Chisholm
# 2                             IGA Denman Prospect        20/3 Felstead Vista
# 3                                   Aldi Chisholm           36 Benham Street
# 4                              41 Charnwood Place                  Charnwood
# ..                                            ...                        ...
# 407               TK Maxx, Canberra Outlet Centre   X20, 337 Canberra Avenue
# 408  U14 girls AFL Ainslie Red vs Belconnen Black      Aranda Playing Fields
# 409         Windsor Smith, Canberra Outlet Centre  T103, 337 Canberra Avenue
# 410                     Assembly The People's Pub         11 Lonsdale Street
# 411                                   Fiction Bar            50 Bunda Street
#
# ...
